# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import pandas_datareader.data as web   # need to pip install this package
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='ticks', context='talk')

# %%
# Downloading the stock data from google finance, (yahoo finance doesn't seem to be working)

# Las Vegas companies from Fortune 500
VegasCompanies={}
VegasCompanies["LVS"]=web.DataReader("LVS", data_source='google', start='2000-01-01',
                    end='2017-07-01')
VegasCompanies["MGM"]=web.DataReader("MGM", data_source='google', start='2000-01-01',
                    end='2017-07-01')
VegasCompanies["CZR"]=web.DataReader("CZR", data_source='google', start='2000-01-01',
                    end='2017-07-01')
VegasCompanies["WYNN"]=web.DataReader("WYNN", data_source='google', start='2000-01-01',
                    end='2017-07-01')

# %%
# Phoenix companies from Fortune 500
PhoenixCompanies={}
PhoenixCompanies["AVT"]=web.DataReader("AVT", data_source='google', start='2000-01-01',
                    end='2017-07-01')
PhoenixCompanies["FCX"]=web.DataReader("FCX", data_source='google', start='2000-01-01',
                    end='2017-07-01')
PhoenixCompanies["RSG"]=web.DataReader("RSG", data_source='google', start='2000-01-01',
                    end='2017-07-01')

# %%
# Dallas companies from Fortune 500
DallasCompanies={}
DallasCompanies["T"]=web.DataReader("T", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["ETE"]=web.DataReader("ETE", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["HFC"]=web.DataReader("HFC", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["LUV"]=web.DataReader("LUV", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["THC"]=web.DataReader("THC", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["TXN"]=web.DataReader("TXN", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["DF"]=web.DataReader("DF", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["TRN"]=web.DataReader("TRN", data_source='google', start='2000-01-01',
                    end='2017-07-01')
DallasCompanies["ADS"]=web.DataReader("ADS", data_source='google', start='2000-01-01',
                    end='2017-07-01')

# %%
# Atlanta companies from Fortune 500
AtlantaCompanies={}
AtlantaCompanies["HD"]=web.DataReader("HD", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["UPS"]=web.DataReader("UPS", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["KO"]=web.DataReader("KO", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["DAL"]=web.DataReader("DAL", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["SO"]=web.DataReader("SO", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["GPC"]=web.DataReader("GPC", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["FDC"]=web.DataReader("FDC", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["HDS"]=web.DataReader("HDS", data_source='google', start='2000-01-01',
                    end='2017-07-01')
AtlantaCompanies["STI"]=web.DataReader("STI", data_source='google', start='2000-01-01',
                    end='2017-07-01')

# %%
# We compute and plot the returns for the Vegas stocks 

VegasRet={}
for stock in ["LVS","MGM","WYNN"]:
    VegasCompanies[stock]=VegasCompanies[stock].resample('M').mean()
    VegasCompanies[stock]=VegasCompanies[stock]["2004-01-31":]
   #print(VegasCompanies[stock].head())
    
    VegasRet[stock]=VegasCompanies[stock].pct_change()
    print(VegasRet[stock].head())
  # VegasCompanies[stock]["Open"].plot()
    VegasRet[stock]["Open"].plot()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2004-12-31       NaN       NaN       NaN       NaN       NaN
# 2005-01-31 -0.056752 -0.088243 -0.065862 -0.081710 -0.748964
# 2005-02-28  0.067447  0.069010  0.069189  0.072325 -0.283101
# 2005-03-31 -0.009170 -0.007352 -0.004134 -0.007211  0.410589
# 2005-04-30 -0.127518 -0.130460 -0.133864 -0.136995  0.101151
#                 Open      High       Low     Close    Volume
# Date
# 2004-01-31       NaN       NaN       NaN       NaN       NaN
# 2004-02-29  0.078214  0.077170  0.080147  0.082615 -0.021243
# 2004-03-31  0.058878  0.061682  0.058580  0.057406 -0.098298
# 2004-04-30  0.040649  0.038011  0.038842  0.038317  0.473573
# 2004-05-31 -0.058006 -0.054793 -0.059986 -0.056330  0.225451
#                 Open      High       Low     Close    Volume
# Date
# 2004-01-31       NaN       NaN       NaN       NaN       NaN
# 2004-02-29  0.173803  0.185875  0.169784  0.184984  0.952521
# ...
