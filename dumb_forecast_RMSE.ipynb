# %%
# %reset -f
# %matplotlib inline

import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import sys, os, copy
#print("Using environment in "+sys.prefix)
#print("Python version "+sys.version)

def getRMSE(x,y):
 # X: Pandas TimeSeries of actual data
 # Y: Either a Pandas TimeSeries of prediction data, OR a Pandas DataFrame with each column as different series 
 diff = x - y    
 if type(y)== pd.core.series.Series:
  return np.sqrt(diff.pow(2).sum()/diff.count())
 else:
  return np.sqrt(diff.pow(2).sum(axis=0) / diff.count(axis=0))


#Load all city data to a pandas dataframe

fname = 'Metro_Zhvi_AllHomes.csv'

metroRegionID = {'Dallas-Fort Worth, TX':394514,
                     'Atlanta, GA':394347,
                     'Phoenix, AZ':394976,
                     'Las Vegas, NV':394775 }

metroString = {'Dallas':u'Dallas-Fort Worth, TX',
               'Atlanta':u'Atlanta, GA',
               'Phoenix':u'Phoenix, AZ',
               'Vegas':u'Las Vegas, NV'}

df = pd.read_csv('Data/ZHVI/'+fname,index_col=[1])
df = df.drop(['RegionID','SizeRank'],axis=1)
df.columns = pd.DatetimeIndex(df.columns)

#Root mean square error, dumb model Atlanta

ts = df.loc[metroString['Atlanta']];
prediction = ts.shift(6).dropna()
ts = ts[prediction.index]
error = ts-prediction
percent_error = error.divide(ts)*100
RMSE_all = np.sqrt(percent_error.pow(2).sum()/percent_error.count())
RMSE_start_2006 = np.sqrt(percent_error['2006-01-01':None].pow(2).sum()/percent_error['2006-01-01':None].count())
print(RMSE_all)
print(RMSE_start_2006)
# Out:
# 3.47271302787
# 4.05406681747

# %%
# %reset -f
# %matplotlib inline

import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import sys, os, copy
#print("Using environment in "+sys.prefix)
#print("Python version "+sys.version)

def getRMSE(x,y):
 # X: Pandas TimeSeries of actual data
 # Y: Either a Pandas TimeSeries of prediction data, OR a Pandas DataFrame with each column as different series 
 diff = x - y    
 if type(y)== pd.core.series.Series:
  return np.sqrt(diff.pow(2).sum()/diff.count())
 else:
  return np.sqrt(diff.pow(2).sum(axis=0) / diff.count(axis=0))


#Load all city data to a pandas dataframe

fname = 'Metro_Zhvi_AllHomes.csv'

metroRegionID = {'Dallas-Fort Worth, TX':394514,
                     'Atlanta, GA':394347,
                     'Phoenix, AZ':394976,
                     'Las Vegas, NV':394775 }

metroString = {'Dallas':u'Dallas-Fort Worth, TX',
               'Atlanta':u'Atlanta, GA',
               'Phoenix':u'Phoenix, AZ',
               'Vegas':u'Las Vegas, NV'}

df = pd.read_csv('Data/ZHVI/'+fname,index_col=[1])
df = df.drop(['RegionID','SizeRank'],axis=1)
df.columns = pd.DatetimeIndex(df.columns)

#Root mean square error, dumb model Dallas

ts = df.loc[metroString['Dallas']];
prediction = ts.shift(6).dropna()
ts = ts[prediction.index]
error = ts-prediction
percent_error = error.divide(ts)*100
RMSE_all = np.sqrt(percent_error.pow(2).sum()/percent_error.count())
RMSE_start_2006 = np.sqrt(percent_error['2006-01-01':None].pow(2).sum()/percent_error['2006-01-01':None].count())
print(RMSE_all)
print(RMSE_start_2006)
# Out:
# 3.12804164629
# 3.34427635703

# %%
# %reset -f
# %matplotlib inline

import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import sys, os, copy
#print("Using environment in "+sys.prefix)
#print("Python version "+sys.version)

def getRMSE(x,y):
 # X: Pandas TimeSeries of actual data
 # Y: Either a Pandas TimeSeries of prediction data, OR a Pandas DataFrame with each column as different series 
 diff = x - y    
 if type(y)== pd.core.series.Series:
  return np.sqrt(diff.pow(2).sum()/diff.count())
 else:
  return np.sqrt(diff.pow(2).sum(axis=0) / diff.count(axis=0))


#Load all city data to a pandas dataframe

fname = 'Metro_Zhvi_AllHomes.csv'

metroRegionID = {'Dallas-Fort Worth, TX':394514,
                     'Atlanta, GA':394347,
                     'Phoenix, AZ':394976,
                     'Las Vegas, NV':394775 }

metroString = {'Dallas':u'Dallas-Fort Worth, TX',
               'Atlanta':u'Atlanta, GA',
               'Phoenix':u'Phoenix, AZ',
               'Vegas':u'Las Vegas, NV'}

df = pd.read_csv('Data/ZHVI/'+fname,index_col=[1])
df = df.drop(['RegionID','SizeRank'],axis=1)
df.columns = pd.DatetimeIndex(df.columns)

#Root mean square error, dumb model Phoenix

ts = df.loc[metroString['Phoenix']];
prediction = ts.shift(6).dropna()
ts = ts[prediction.index]
error = ts-prediction
percent_error = error.divide(ts)*100
RMSE_all = np.sqrt(percent_error.pow(2).sum()/percent_error.count())
RMSE_start_2006 = np.sqrt(percent_error['2006-01-01':None].pow(2).sum()/percent_error['2006-01-01':None].count())
print(RMSE_all)
print(RMSE_start_2006)
# Out:
# 6.8277819456
# 7.07415498164

# %%
# %reset -f
# %matplotlib inline

import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import sys, os, copy
#print("Using environment in "+sys.prefix)
#print("Python version "+sys.version)

def getRMSE(x,y):
 # X: Pandas TimeSeries of actual data
 # Y: Either a Pandas TimeSeries of prediction data, OR a Pandas DataFrame with each column as different series 
 diff = x - y    
 if type(y)== pd.core.series.Series:
  return np.sqrt(diff.pow(2).sum()/diff.count())
 else:
  return np.sqrt(diff.pow(2).sum(axis=0) / diff.count(axis=0))


#Load all city data to a pandas dataframe

fname = 'Metro_Zhvi_AllHomes.csv'

metroRegionID = {'Dallas-Fort Worth, TX':394514,
                     'Atlanta, GA':394347,
                     'Phoenix, AZ':394976,
                     'Las Vegas, NV':394775 }

metroString = {'Dallas':u'Dallas-Fort Worth, TX',
               'Atlanta':u'Atlanta, GA',
               'Phoenix':u'Phoenix, AZ',
               'Vegas':u'Las Vegas, NV'}

df = pd.read_csv('Data/ZHVI/'+fname,index_col=[1])
df = df.drop(['RegionID','SizeRank'],axis=1)
df.columns = pd.DatetimeIndex(df.columns)

#Root mean square error, dumb model Vegas

ts = df.loc[metroString['Vegas']];
prediction = ts.shift(6).dropna()
ts = ts[prediction.index]
error = ts-prediction
percent_error = error.divide(ts)*100
RMSE_all = np.sqrt(percent_error.pow(2).sum()/percent_error.count())
RMSE_start_2006 = np.sqrt(percent_error['2006-01-01':None].pow(2).sum()/percent_error['2006-01-01':None].count())
print(RMSE_all)
print(RMSE_start_2006)
# Out:
# 8.198821836
# 9.16364157722
